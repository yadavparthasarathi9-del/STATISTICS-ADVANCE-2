# %% [markdown]
# #**1**
#
#
# A statistical technique for determining whether a claim (hypothesis) about a population has sufficient evidence in a sample of data to support or refute it is called hypothesis testing.
#
#  It includes:
#
#  The default assumption (no effect or no difference) is known as the null hypothesis (H₀).
#
#  What you wish to test or prove is known as the alternative hypothesis (H₁).
#
#  The test statistic, also known as the p-value, is used to determine whether to reject H₀.
#
#  ✅  If the p-value is less than the significance level (α), then reject H₀.  Failure to reject H₀ if p-value ≥ α

# %% [markdown]
# #**2**
# The null hypothesis (H₀) states that there is no effect or no difference — it’s the default assumption.
# The alternative hypothesis (H₁ or Ha) states that there is an effect or a difference — it’s what you want to prove.
#
# 👉 Example:
#
# H₀: The mean weight = 70 kg
#
# H₁: The mean weight ≠ 70 kg

# %% [markdown]
# #**3**
# The significance level (α) is the threshold for deciding whether to reject the null hypothesis.
#
# It represents the probability of making a Type I error — rejecting H₀ when it’s actually true.
#
# Common values: 0.05, 0.01, or 0.10.
#
# 🔹 If p-value < α: Reject H₀ (evidence supports H₁)
# 🔹 If p-value ≥ α: Fail to reject H₀ (not enough evidence against H₀)
#
# So, α controls how strict the test is in detecting a true effect.

# %% [markdown]
# #**4**
#
#
# Type I Error (False Positive):
# Rejecting the null hypothesis when it is actually true.
# 👉 Example: Concluding a new drug works when it actually doesn’t.
#
# Type II Error (False Negative):
# Failing to reject the null hypothesis when it is actually false.
# 👉 Example: Concluding a new drug doesn’t work when it actually does.

# %% [markdown]
# #**5**
# **Z-test:**
#
# * Used when **sample size is large (n > 30)**
# * **Population standard deviation (σ)** is known
# * Follows a **normal distribution**
#
# **T-test:**
#
# * Used when **sample size is small (n ≤ 30)**
# * **Population standard deviation (σ)** is unknown (use sample SD instead)
# * Follows a **t-distribution**

# %%
#6
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10     # number of trials
p = 0.5    # probability of success
size = 1000  # number of experiments

# Generate binomial data
data = np.random.binomial(n, p, size)

# Plot histogram
plt.hist(data, bins=range(n+2), edgecolor='black', alpha=0.7)
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Frequency")
plt.show()

# %%
#7
import numpy as np
from scipy import stats

# Sample data
sample_data = [49.1, 50.2, 51.0, 48.7, 50.5, 49.8, 50.3, 50.7, 50.2, 49.6,
               50.1, 49.9, 50.8, 50.4, 48.9, 50.6, 50.0, 49.7, 50.2, 49.5,
               50.1, 50.3, 50.4, 50.5, 50.0, 50.7, 49.3, 49.8, 50.2, 50.9,
               50.3, 50.4, 50.0, 49.7, 50.5, 49.9]

# Hypothesized population mean
mu_0 = 50

# Calculate sample statistics
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)
n = len(sample_data)

# Z-test statistic
z_stat = (sample_mean - mu_0) / (sample_std / np.sqrt(n))

# p-value for two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

print(f"Sample Mean = {sample_mean:.3f}")
print(f"Z-statistic = {z_stat:.3f}")
print(f"P-value = {p_value:.4f}")

# Significance level
alpha = 0.05

if p_value < alpha:
    print(" Reject the null hypothesis (H₀). There is a significant difference.")
else:
    print(" Fail to reject the null hypothesis (H₀). No significant difference.")
# Out:
# Sample Mean = 50.089
# Z-statistic = 0.994
# P-value = 0.3202
#  Fail to reject the null hypothesis (H₀). No significant difference.

# %%
#8
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate data from a normal distribution
np.random.seed(0)  # for reproducibility
data = np.random.normal(loc=50, scale=5, size=100)  # mean=50, std=5, n=100

# Step 2: Calculate sample statistics
mean = np.mean(data)
std_dev = np.std(data, ddof=1)
n = len(data)

# Step 3: Calculate 95% confidence interval for the mean
confidence = 0.95
alpha = 1 - confidence
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)  # two-tailed t critical value
margin_of_error = t_critical * (std_dev / np.sqrt(n))

ci_lower = mean - margin_of_error
ci_upper = mean + margin_of_error

print(f"Sample Mean = {mean:.2f}")
print(f"95% Confidence Interval = ({ci_lower:.2f}, {ci_upper:.2f})")

# Step 4: Plot the data
plt.figure(figsize=(8, 5))
plt.hist(data, bins=15, edgecolor='black', alpha=0.7)
plt.axvline(mean, color='red', linestyle='--', label=f"Mean = {mean:.2f}")
plt.axvline(ci_lower, color='green', linestyle='--', label=f"Lower 95% CI = {ci_lower:.2f}")
plt.axvline(ci_upper, color='green', linestyle='--', label=f"Upper 95% CI = {ci_upper:.2f}")

plt.title("Normal Distribution with 95% Confidence Interval")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Sample Mean = 50.30
# 95% Confidence Interval = (49.29, 51.30)

# %%
#9
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate Z-scores and plot histogram
def z_score_analysis(data):
    # Calculate mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)

    # Calculate Z-scores
    z_scores = (data - mean) / std_dev

    # Display results
    print(f"Mean: {mean:.2f}, Standard Deviation: {std_dev:.2f}")
    print("First 5 Z-scores:", z_scores[:5])

    # Plot histogram of Z-scores
    plt.figure(figsize=(8,5))
    plt.hist(z_scores, bins=15, edgecolor='black', alpha=0.7)
    plt.title("Histogram of Z-scores (Standardized Data)")
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.axvline(0, color='red', linestyle='--', label="Mean (Z=0)")
    plt.legend()
    plt.show()

    return z_scores

# Example dataset
data = np.random.normal(loc=50, scale=5, size=100)

# Call the function
z_scores = z_score_analysis(data)
# Out:
# Mean: 50.41, Standard Deviation: 5.20
# First 5 Z-scores: [ 1.73206395 -1.37494016 -1.30062957  0.8533525  -1.2070018 ]

# %% [markdown]
# Z Score reprsents that
#
# They measure how many standard deviations each data point is from the mean.
#
# A Z = 0 means the value is exactly at the mean.
#
# Positive Z → above the mean; Negative Z → below the mean.
#
# Example: Z = 2 means the value is 2 standard deviations above the mean.
